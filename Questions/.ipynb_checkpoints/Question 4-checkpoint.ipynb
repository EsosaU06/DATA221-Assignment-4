# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import load_breast_cancer
breastCancerData =  load_breast_cancer(as_frame = True)
import tensorflow as tf
tf.random.set_seed(5)

from tensorflow.keras.models import Sequential
neural_network_model = Sequential()

from tensorflow.keras.layers import Dense, InputLayer

# %%
breastCancerData_X = breastCancerData.data
breastCancerData_y = breastCancerData.target

# %%
features_train, features_test, labels_train, labels_test = train_test_split(breastCancerData_X, breastCancerData_y, test_size=0.30, random_state=5)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
features_train = imputer.fit_transform(features_train)

scaler = StandardScaler()

features_train = scaler.fit_transform(X=features_train)
features_test = scaler.transform(X=features_test)
# Out:
# C:\Users\shibs\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
input_layer = InputLayer(shape=(30,))
neural_network_model.add(input_layer)
hidden_layer = Dense(2) 
neural_network_model.add(hidden_layer)
output_layer = Dense(1, activation="sigmoid")
neural_network_model.add(output_layer)

# %%
neural_network_model.compile(loss="binary_crossentropy", metrics=["accuracy"])

# %%
neural_network_model.fit(features_train, labels_train, epochs=10)
# Out:
# Epoch 1/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5251 - loss: 0.9223
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6131 - loss: 0.7649
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6784 - loss: 0.6638
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7111 - loss: 0.5829
# Epoch 5/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7538 - loss: 0.5155
# Epoch 6/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8015 - loss: 0.4588
# Epoch 7/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8291 - loss: 0.4107
# Epoch 8/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8568 - loss: 0.3700
# Epoch 9/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8668 - loss: 0.3353
# Epoch 10/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8819 - loss: 0.3057

# %%
training_preformance = neural_network_model.evaluate(features_train, labels_train)
print("training accuracy: ",training_preformance[1])
testing_preformance = neural_network_model.evaluate(features_test, labels_test)
print("testing accuracy: ",testing_preformance[1])
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8869 - loss: 0.2900
# training accuracy:  0.8869346976280212
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8889 - loss: 0.3218
# testing accuracy:  0.8888888955116272

# %%
"""
1. feature scaling is necessary for neural networks because it improves their accuracy and effeciency by removing the impact large values in would have in training from the dataset.
Neural networks are more accurate when the values are in a consitent range bounded by a small number, such as 0 and 1.

2. an epoch represents how many times the neural network learns from the datasets, makes predictions (both are done in forward passes), and assesses those predictions by adjusting its weights (done in backward pass).
"""
