# %%
from sklearn.datasets import load_breast_cancer
breastCancerData =  load_breast_cancer(as_frame = True)
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer

from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

tf.random.set_seed(5)


neural_network_model = Sequential()

breastCancerData_X = breastCancerData.data
breastCancerData_y = breastCancerData.target

features_train, features_test, labels_train, labels_test = train_test_split(breastCancerData_X, breastCancerData_y, test_size=0.30, random_state=5)

imputer = SimpleImputer(strategy='mean')
features_train = imputer.fit_transform(features_train)

scaler = StandardScaler()

features_train = scaler.fit_transform(X=features_train)
features_test = scaler.transform(X=features_test)
# Out:
# C:\Users\shibs\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
input_layer = InputLayer(shape=(30,))
neural_network_model.add(input_layer)
hidden_layer = Dense(2) 
neural_network_model.add(hidden_layer)
output_layer = Dense(1, activation="sigmoid")
neural_network_model.add(output_layer)
neural_network_model.compile(loss="binary_crossentropy")
neural_network_model.fit(features_train, labels_train, epochs=10)
# Out:
# Epoch 1/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4856
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4134
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3660
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3277
# Epoch 5/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2958
# Epoch 6/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2689
# Epoch 7/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2460
# Epoch 8/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2264
# Epoch 9/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2095
# Epoch 10/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1949

# %%
from sklearn import tree
import numpy

from sklearn import datasets
iris_dataset = datasets.load_iris()
feature_matrix = iris_dataset.data
target_labels = iris_dataset.target

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

features_train, features_test, labels_train, labels_test = train_test_split(feature_matrix, target_labels, test_size=0.20, random_state=5)

decision_tree_classifier = DecisionTreeClassifier(criterion="entropy", max_depth=3)

decision_tree_classifier.fit(features_train, labels_train)

predicted_test_labels = decision_tree_classifier.predict(features_test)

# %%
cf1 = confusion_matrix(predicted_test_labels_decisionTree, y_test)
cf2 = confusion_matrix(predicted_test_labels_decisionTree_NN, y_test)

"""
i only realized i forgot to do this 10 minutes before the deadline, i cannot find
the function to do this
"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cf1 = confusion_matrix(predicted_test_labels_decisionTree, y_test)
#       2 cf2 = confusion_matrix(predicted_test_labels_decisionTree_NN, y_test)
#
# NameError: name 'confusion_matrix' is not defined

# %%
"""
Personally I would prefer decision trees for this task.

An advantage of decision trees is that they are easier to understand and work with than neural networks.
A distadvantage is that they cannot find patterns as effectively as neural networks can.

An advantage of neural networks is that they tend to be more accurate than simpler models like decision trees.
However, one disadvantage is that they are more resource heavy than decision trees.
"""
